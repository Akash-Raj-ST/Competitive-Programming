# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/My Drive/CSE4020/Lab3
# Out:
# /content/gdrive/My Drive/CSE4020/Lab3

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

# %%
file_name = "housePrice.csv"
dependent_col = "SalePrice"

df = pd.read_csv(file_name)

if "Id" in df.columns:
  df = df.drop("Id",axis=1)

transform_col = []

for col in df.columns:
  if not str(df[col][0]).isdigit():
    transform_col.append(col)

label_encoder = preprocessing.LabelEncoder()

for t_col in transform_col:
  df[t_col] = label_encoder.fit_transform(df[t_col])
print(df)
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0             60         3           36     8450       1      2         3
# 1             20         3           51     9600       1      2         3
# 2             60         3           39    11250       1      2         0
# 3             70         3           31     9550       1      2         0
# 4             60         3           55    14260       1      2         0
# ...          ...       ...          ...      ...     ...    ...       ...
# 1455          60         3           33     7917       1      2         3
# 1456          20         3           56    13175       1      2         3
# 1457          70         3           37     9042       1      2         3
# 1458          20         3           39     9717       1      2         3
# 1459          20         3           46     9937       1      2         3
#
#       LandContour  Utilities  LotConfig  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
x = df.drop(dependent_col,axis=1)
y = df[dependent_col]

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)

model = LinearRegression()
model.fit(x_train,y_train)

prediction = model.predict(x_test)
print(prediction)
model.score(x_test,y_test)
# Out:
# [156533.17791711 196618.71334282 158498.4654864  328292.8080642
#   85326.37128053 197331.20009415 300719.33902216 113391.45843191
#  200833.4172719  171265.0508063  153172.31395877 107924.14352184
#  246917.13681785 251495.68441763 185626.36850501 300203.89043331
#  298494.38916714 201825.13458242 194882.0163735  185745.76785141
#  141895.7570957  170394.40451658 140970.43654875 203517.76724531
#  246559.79055212  83679.98053484 214659.71237954 146210.58728243
#  358924.93783665 322340.41555879 153220.23681327 111178.1075987
#  184223.17116345  97508.25758133 117547.81385746 157842.21156419
#  222114.25069958  89953.83927455 403802.0671558   96212.02561457
#  384283.72039812 162047.51311025 121089.10933587 169977.2880782
#  249077.51013784 246270.52234011 122706.28717307 188793.9145173
#   84380.32359325 109852.7716664  162125.52108342 115823.8207733
#  206308.53765222 272365.12601006 231615.26862638 188405.86452717
#  147063.92704156 279573.02702126 185288.93311036 119641.03003023
# ...
